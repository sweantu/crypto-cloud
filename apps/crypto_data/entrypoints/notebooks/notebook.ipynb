# %%
# spark.sql(f"""
# CREATE DATABASE IF NOT EXISTS {transform_db}
# LOCATION 's3a://{DATA_LAKE_BUCKET}/transform_zone/'
# """).show()

# %%
import os
from shared_lib.spark import get_spark_session
DATA_LAKE_BUCKET = os.getenv("DATA_LAKE_BUCKET", "")
transform_db = f"hive_catalog.{os.getenv('TRANSFORM_DB', '')}"
spark = get_spark_session(app_name="example_app", iceberg=True)
# Out:
# 26/02/10 14:24:17 WARN Utils: Your hostname, Nguyens-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.1.15 instead (on interface en0)
# 26/02/10 14:24:17 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/anhtu/.ivy2/cache
# The jars for the packages stored in: /Users/anhtu/.ivy2/jars
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# org.apache.iceberg#iceberg-aws-bundle added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-44c2e9c2-4fdb-4a89-9f4c-42cacd708c44;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.7.1 in central
# 	found org.apache.iceberg#iceberg-aws-bundle;1.7.1 in central
# ...

# %%
spark.sql(f"""
show tables in {transform_db}
""").show()
# Out:
# +------------+-------------+-----------+
# |   namespace|    tableName|isTemporary|
# +------------+-------------+-----------+
# |transform_db|    aggtrades|      false|
# |transform_db|       klines|      false|
# |transform_db|  pattern_two|      false|
# |transform_db|         rsi6|      false|
# |transform_db|         macd|      false|
# |transform_db|  pattern_one|      false|
# |transform_db|pattern_three|      false|
# +------------+-------------+-----------+

# %%
spark.sql(f"""
select * from {transform_db}.rsi6 order by group_id desc limit 20
""").show()
# Out:
# +--------+-------------------+----------------+----------+----------+---------+-----------+--------+----------------+------------+-------+-----+--------+-------+
# |group_id|         group_date|       open_time|open_price|high_price|low_price|close_price|  volume|      close_time|landing_date| symbol| rsi6|  rsi_ag| rsi_al|
# +--------+-------------------+----------------+----------+----------+---------+-----------+--------+----------------+------------+-------+-----+--------+-------+
# | 1954463|2025-09-27 23:45:00|1759016701408514|    0.7814|    0.7825|   0.7807|     0.7809|132144.3|1759017599501352|  2025-09-27|ADAUSDT|35.08|  4.0E-4| 7.4E-4|
# | 1954462|2025-09-27 23:30:00|1759015804476897|    0.7814|    0.7821|   0.7806|     0.7814|188230.3|1759016697090778|  2025-09-27|ADAUSDT|37.84|  4.8E-4|7.88E-4|
# | 1954461|2025-09-27 23:15:00|1759014900390169|    0.7834|    0.7839|   0.7811|     0.7815|260574.1|1759015796003399|  2025-09-27|ADAUSDT|38.35| 5.76E-4|9.26E-4|
# ...
