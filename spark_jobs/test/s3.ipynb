# %%
import os
from pyspark.sql import SparkSession

# %%
DATA_LAKE_BUCKET = os.getenv("DATA_LAKE_BUCKET")

# %%
spark = (
    SparkSession.builder
    .appName("S3Test")
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4")
    .config("spark.hadoop.fs.s3.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .getOrCreate()
)
# Out:
# 25/11/19 15:38:03 WARN Utils: Your hostname, Nguyens-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.1.9 instead (on interface en0)
# 25/11/19 15:38:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/anhtu/.ivy2/cache
# The jars for the packages stored in: /Users/anhtu/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-b7f85684-e72b-42f6-b1b8-13a597d1fe6b;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/Users/anhtu/.pyenv/versions/3.11.11/envs/crypto-cloud/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found org.apache.hadoop#hadoop-aws;3.3.4 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.262 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# :: resolution report :: resolve 101ms :: artifacts dl 3ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.12.262 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.4 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-b7f85684-e72b-42f6-b1b8-13a597d1fe6b
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/2ms)
# 25/11/19 15:38:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
data = [(1, "Alice"), (2, "Bob")]
df = spark.createDataFrame(data, ["id", "name"])

# %%
df.show()
# Out:
# +---+-----+
# | id| name|
# +---+-----+
# |  1|Alice|
# |  2|  Bob|
# +---+-----+

# %%
df.write.mode("overwrite").parquet(f"s3://{DATA_LAKE_BUCKET}/testdata/")
print("✅ Successfully wrote parquet to S3!")
# Out:
# 25/11/19 15:38:32 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# ✅ Successfully wrote parquet to S3!

# %%
df = spark.read.parquet(f"s3://{DATA_LAKE_BUCKET}/testdata/")

# %%
df.show()
# Out:
# +---+-----+
# | id| name|
# +---+-----+
# |  1|Alice|
# |  2|  Bob|
# +---+-----+
